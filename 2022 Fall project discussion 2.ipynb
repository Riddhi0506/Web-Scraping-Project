# %%
import urllib.request

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}

req = urllib.request.Request('https://www.metacritic.com/movie/beauty-and-the-beast-1991', headers = headers)
fhand = urllib.request.urlopen(req)

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
soup = BeautifulSoup(fhand, 'html.parser') 
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://ogp.me/ns/fb#" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Beauty and the Beast (1991) Reviews - Metacritic</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Beauty and the Beast movie reviews &amp; Metacritic score: This 'tale as old as time' follows the adventures of Belle, a bright young woman who finds herself imp..." name="description"/>
# <meta content="Metacritic" name="application-name"/>
# <meta content="#000000" name="msapplication-TileColor"/>
# <meta content="/images/win8tile/76bf1426-2886-4b87-ae1c-06424b6bb8a2.png" name="msapplication-TileImage"/>
# <meta content="618k3mbeki8tar7u6wvrum5lxs5cka" name="facebook-domain-verification">
# <meta content="Beauty and the Beast" property="og:title"/>
# <meta content="video.movie" property="og:type"/>
# <meta content="https://www.metacritic.com/movie/beauty-and-the-beast-1991" property="og:url"/>
# ...

# %%
director_div = soup.find('div', attrs = {'class':'director'})

print(director_div)
# Out:
# <div class="director">
# <span class="label">Director:</span>
# <a href="/person/gary-trousdale"><span>Gary Trousdale</span></a> and <a href="/person/kirk-wise"><span>Kirk Wise</span></a> </div>

# %%
director_link = director_div.find_all('a')

# %%
director_link
# Out:
# [<a href="/person/gary-trousdale"><span>Gary Trousdale</span></a>,
#  <a href="/person/kirk-wise"><span>Kirk Wise</span></a>]

# %%
for i in director_link:
    print(i.get_text())
# Out:
# Gary Trousdale
# Kirk Wise

# %%
genres_div = soup.find('div', attrs = {'class':'genres'})

print(genres_div)
# Out:
# <div class="genres">
# <span class="label">Genre(s):</span>
# <span>
# <span>Fantasy</span>,                                                                                                    <span>Romance</span>,                                                                                                    <span>Animation</span>,                                                                                                    <span>Family</span>,                                                                                                    <span>Musical</span> </span>
# </div>

# %%
genres_list = genres_div.find_all('span')

# %%
genres = []
for i in genres_list:
    genres.append(i.get_text())

# %%
genres
# Out:
# ['Genre(s):',
#  '\nFantasy,                                                                                                    Romance,                                                                                                    Animation,                                                                                                    Family,                                                                                                    Musical ',
#  'Fantasy',
#  'Romance',
#  'Animation',
#  'Family',
#  'Musical']

# %%
len(genres)
# Out:
# 7

# %%
set(genres)
# Out:
# {'\nFantasy,                                                                                                    Romance,                                                                                                    Animation,                                                                                                    Family,                                                                                                    Musical ',
#  'Animation',
#  'Family',
#  'Fantasy',
#  'Genre(s):',
#  'Musical',
#  'Romance'}

# %%
genres[2:]
# Out:
# ['Fantasy', 'Romance', 'Animation', 'Family', 'Musical']

# %%
list - name, director, and genres list can be created.
make use of dict. use movie name as key1. use other dict for value where director is key2 and genre is value2.
writing loop to go through 500 movies.
#crete sub dict inside of the loop. key - movie and value = director and genre.
#below loop will create the dict in dict for movies and directors and genre.
dict500 = {}
for i in 500_urls:
    name = get_name()
    director = get_director()
    genres = get_genres()
    sub_dict = {}
    sub_dict[director]=genres
    dict500[name] = sub_dict

# %%
#some movies can have more than 2 directors. for this directors while findall will return a list.
#but key in dict does not take list. 
#convert the directors list to tuples. so tat we can use directores as key2.

# %%
#how to take the movie name:
#how to get ride of the special character - use replace, substitute.
#for duplicate names of movies

hper = soup.find('div', attrs = {'class':'___<name of the class where we wat to take the data>'})
name = title[0].get_text().strip.replace('\n', ' ')
name

#put movies, genres, directors in list. one or more names can exists  in either pf the one
#list cannot be used as key so make is tuple. 
#sub_dict[tuple(directors)] = genres[2:]

# %%
#how to remove the special characters in the csv file.
movie_writer.writerow([key1, ', ', join(list(key2)) , ', ' join(value2)]) # while writing the data in csv file.
add this in open statement after mode in order remove the extra line, newline = ''
#uses genre[2:]
